# %% [markdown]
# # Working With APIs and JSON

# %% [markdown]
# #### Save API key

# %%
api_key = 'api_key=6b5924df7b618eb4d70fc47936cad3cf'

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import requests

# %% [markdown]
# ## Creating Query

# %%
# We will fetch the data from TMDB website. Here we will work on a small query.
# We will ask for data of a movie by it's id number.
# We know the id before making our request. It is not possible in real case.
# id is 547016, and movie is 'The old Guard'

# We need 3 things to get the movie data.
# 1) url: from where we will ask for the data.
# 2) movie id: who's data is asked.
# 3) api_key: for authentication on DATABASE.

# %%
movie_api = 'https://api.themoviedb.org/3/movie/{}?'
movie_api
# Out:
# 'https://api.themoviedb.org/3/movie/{}?'

# %%
movie_id = 547016
movie_id
# Out:
# 547016

# %%
# To undersatnd What's happening in query.

print('hello no {}, {} + {} = {} ?'.format(5,2,2,4) + 'Yes!!')
# Out:
# hello no 5, 2 + 2 = 4 ?Yes!!

# %%
url = movie_api.format(movie_id) + api_key
url
# Out:
# 'https://api.themoviedb.org/3/movie/547016?api_key=6b5924df7b618eb4d70fc47936cad3cf'

# %% [markdown]
# # Sending get() request and saving the response.
# #### requests.get()

# %%
# Now we can do 2 things.

# 1) we can paste this query in browser. Try it. But the we can copy that data into file. 
# 2) We can save data into pyton variable. Then we can manipulate it. 
# We will do that by using requests module. We will send a get request using get() method of the module.
# We will save the responce objet from the database into the response variable.

# work of get() = Sends a GET request. 

response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
type(response)
# Out:
# requests.models.Response

# %%
# To know the mean of reponse = 200 we need to see the documentation page of the website.
# 200 mean everything is OK.

# %% [markdown]
# ### Extracting response Data.
# #### response.json()<br>my_response.json()

# %%
# Now we will parse the json data from the response object
# work of json = Returns the json-encoded content of a response, if any.

data = response.json()
data
# Out:
# {'adult': False,
#  'backdrop_path': '/m0ObOaJBerZ3Unc74l471ar8Iiy.jpg',
#  'belongs_to_collection': None,
#  'budget': 70000000,
#  'genres': [{'id': 28, 'name': 'Action'}, {'id': 14, 'name': 'Fantasy'}],
#  'homepage': 'https://www.netflix.com/title/81038963',
#  'id': 547016,
#  'imdb_id': 'tt7556122',
#  'original_language': 'en',
#  'original_title': 'The Old Guard',
#  'overview': "Four undying warriors who've secretly protected humanity for centuries become targeted for their mysterious powers just as they discover a new immortal.",
#  'popularity': 146.482,
#  'poster_path': '/cjr4NWURcVN3gW5FlHeabgBHLrY.jpg',
#  'production_companies': [{'id': 82819,
#    'logo_path': '/5Z8WWr0Lf1tInVWwJsxPP0uMz9a.png',
#    'name': 'Skydance Media',
#    'origin_country': 'US'},
#   {'id': 3574,
#    'logo_path': '/j3iU6FoWplGPoO1Vxn8fFHX4VPE.png',
#    'name': 'Denver and Delilah Productions',
#    'origin_country': 'US'},
#   {'id': 19477,
#    'logo_path': None,
#    'name': 'Dune Films',
#    'origin_country': 'MA'}],
#  'production_countries': [{'iso_3166_1': 'US',
#    'name': 'United States of America'}],
#  'release_date': '2020-07-10',
#  'revenue': 0,
#  'runtime': 124,
#  'spoken_languages': [{'iso_639_1': 'en', 'name': 'English'},
#   {'iso_639_1': 'ar', 'name': 'العربية'},
#   {'iso_639_1': 'it', 'name': 'Italiano'},
#   {'iso_639_1': 'fr', 'name': 'Français'},
#   {'iso_639_1': 'ru', 'name': 'Pусский'}],
#  'status': 'Released',
#  'tagline': 'Forever is harder than it looks',
#  'title': 'The Old Guard',
#  'video': False,
#  'vote_average': 7.4,
#  'vote_count': 1407}

# %%
type(data)
# Out:
# dict

# %% [markdown]
# ## Creating DataFrame from data

# %%
# Now we will create a DataFrame from it.

# df = pd.DataFrame(data)

# This will generate a error. Try it.

# %% [markdown]
# #### ValueError: arrays must all be same length

# %%
# It will not work.
# So first we will create a series from it and then create a DataFrame from that series.

pd.Series(data)
# Out:
# adult                                                                False
# backdrop_path                             /m0ObOaJBerZ3Unc74l471ar8Iiy.jpg
# belongs_to_collection                                                 None
# budget                                                            70000000
# genres                   [{'id': 28, 'name': 'Action'}, {'id': 14, 'nam...
# homepage                            https://www.netflix.com/title/81038963
# id                                                                  547016
# imdb_id                                                          tt7556122
# original_language                                                       en
# original_title                                               The Old Guard
# overview                 Four undying warriors who've secretly protecte...
# popularity                                                         146.482
# poster_path                               /cjr4NWURcVN3gW5FlHeabgBHLrY.jpg
# production_companies     [{'id': 82819, 'logo_path': '/5Z8WWr0Lf1tInVWw...
# production_countries     [{'iso_3166_1': 'US', 'name': 'United States o...
# release_date                                                    2020-07-10
# revenue                                                                  0
# runtime                                                                124
# spoken_languages         [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# status                                                            Released
# tagline                                    Forever is harder than it looks
# title                                                        The Old Guard
# video                                                                False
# vote_average                                                           7.4
# vote_count                                                            1407
# dtype: object

# %%
# Now We can create dataframe in 2 ways.

df = pd.DataFrame(pd.Series(data))
df
# Out:
#                                                                        0
# adult                                                              False
# backdrop_path                           /m0ObOaJBerZ3Unc74l471ar8Iiy.jpg
# belongs_to_collection                                               None
# budget                                                          70000000
# genres                 [{'id': 28, 'name': 'Action'}, {'id': 14, 'nam...
# homepage                          https://www.netflix.com/title/81038963
# id                                                                547016
# imdb_id                                                        tt7556122
# original_language                                                     en
# original_title                                             The Old Guard
# overview               Four undying warriors who've secretly protecte...
# popularity                                                       146.482
# poster_path                             /cjr4NWURcVN3gW5FlHeabgBHLrY.jpg
# production_companies   [{'id': 82819, 'logo_path': '/5Z8WWr0Lf1tInVWw...
# production_countries   [{'iso_3166_1': 'US', 'name': 'United States o...
# release_date                                                  2020-07-10
# revenue                                                                0
# runtime                                                              124
# spoken_languages       [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# status                                                          Released
# tagline                                  Forever is harder than it looks
# title                                                      The Old Guard
# video                                                              False
# vote_average                                                         7.4
# vote_count                                                          1407

# %% [markdown]
# #### to_frame()

# %%
# 2nd way

df2 = pd.Series(data).to_frame()

# %%
df2
# Out:
#                                                                        0
# adult                                                              False
# backdrop_path                           /m0ObOaJBerZ3Unc74l471ar8Iiy.jpg
# belongs_to_collection                                               None
# budget                                                          70000000
# genres                 [{'id': 28, 'name': 'Action'}, {'id': 14, 'nam...
# homepage                          https://www.netflix.com/title/81038963
# id                                                                547016
# imdb_id                                                        tt7556122
# original_language                                                     en
# original_title                                             The Old Guard
# overview               Four undying warriors who've secretly protecte...
# popularity                                                       146.482
# poster_path                             /cjr4NWURcVN3gW5FlHeabgBHLrY.jpg
# production_companies   [{'id': 82819, 'logo_path': '/5Z8WWr0Lf1tInVWw...
# production_countries   [{'iso_3166_1': 'US', 'name': 'United States o...
# release_date                                                  2020-07-10
# revenue                                                                0
# runtime                                                              124
# spoken_languages       [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# status                                                          Released
# tagline                                  Forever is harder than it looks
# title                                                      The Old Guard
# video                                                              False
# vote_average                                                         7.4
# vote_count                                                          1407

# %% [markdown]
# #### transpose the DataFrame

# %%
# But we need column vise data not row vise.
# So we will apply transepose method to convert rows into column.

df.T
# Out:
#    adult                     backdrop_path belongs_to_collection    budget  \
# 0  False  /m0ObOaJBerZ3Unc74l471ar8Iiy.jpg                  None  70000000
#
#                                               genres  \
# 0  [{'id': 28, 'name': 'Action'}, {'id': 14, 'nam...
#
#                                  homepage      id    imdb_id  \
# 0  https://www.netflix.com/title/81038963  547016  tt7556122
#
#   original_language original_title  ... release_date revenue runtime  \
# 0                en  The Old Guard  ...   2020-07-10       0     124
#
#                                     spoken_languages    status  \
# 0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
#
#                            tagline          title  video vote_average  \
# 0  Forever is harder than it looks  The Old Guard  False          7.4
#
#   vote_count
# 0       1407
#
# [1 rows x 25 columns]

# %%
df3 = pd.Series(data).to_frame().T
df3
# Out:
#    adult                     backdrop_path belongs_to_collection    budget  \
# 0  False  /m0ObOaJBerZ3Unc74l471ar8Iiy.jpg                  None  70000000
#
#                                               genres  \
# 0  [{'id': 28, 'name': 'Action'}, {'id': 14, 'nam...
#
#                                  homepage      id    imdb_id  \
# 0  https://www.netflix.com/title/81038963  547016  tt7556122
#
#   original_language original_title  ... release_date revenue runtime  \
# 0                en  The Old Guard  ...   2020-07-10       0     124
#
#                                     spoken_languages    status  \
# 0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
#
#                            tagline          title  video vote_average  \
# 0  Forever is harder than it looks  The Old Guard  False          7.4
#
#   vote_count
# 0       1407
#
# [1 rows x 25 columns]

# %% [markdown]
# # Normalization

# %%
# Yes we can apply normlaize function also.
# remember normalize works on raw data(json format) not on DataFrame.
# Notice returned DataFrame is already Transposed.
# json_normalize() knows it is a single row.

# %%
pd.json_normalize(data=data, sep='_')
# Out:
#    adult                     backdrop_path belongs_to_collection    budget  \
# 0  False  /m0ObOaJBerZ3Unc74l471ar8Iiy.jpg                  None  70000000
#
#                                               genres  \
# 0  [{'id': 28, 'name': 'Action'}, {'id': 14, 'nam...
#
#                                  homepage      id    imdb_id  \
# 0  https://www.netflix.com/title/81038963  547016  tt7556122
#
#   original_language original_title  ... release_date  revenue runtime  \
# 0                en  The Old Guard  ...   2020-07-10        0     124
#
#                                     spoken_languages    status  \
# 0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
#
#                            tagline          title  video vote_average  \
# 0  Forever is harder than it looks  The Old Guard  False          7.4
#
#   vote_count
# 0       1407
#
# [1 rows x 25 columns]

# %%
pd.json_normalize(data=data, record_path='genres', meta='title')
# Out:
#    id     name          title
# 0  28   Action  The Old Guard
# 1  14  Fantasy  The Old Guard

# %%
pd.json_normalize(data=data, record_path='production_companies', meta='title')
# Out:
#       id                         logo_path                            name  \
# 0  82819  /5Z8WWr0Lf1tInVWwJsxPP0uMz9a.png                  Skydance Media
# 1   3574  /j3iU6FoWplGPoO1Vxn8fFHX4VPE.png  Denver and Delilah Productions
# 2  19477                              None                      Dune Films
#
#   origin_country          title
# 0             US  The Old Guard
# 1             US  The Old Guard
# 2             MA  The Old Guard

# %% [markdown]
# # Part 2

# %%
# In Part 1 we have created a query for movies database.
# Now we will create query for discover database.

# %%
discover_api = 'https://api.themoviedb.org/3/discover/movie?'

# %%
query = '&primary_release_date.gte=2020-01-01&primary_release_date.lte=2020-07-29'

# %%
url = discover_api + api_key + query

# %%
data = requests.get(url).json()

# %%
data
# Out:
# {'page': 1,
#  'total_results': 8529,
#  'total_pages': 427,
#  'results': [{'popularity': 303.903,
#    'vote_count': 2357,
#    'video': False,
#    'poster_path': '/mb7wQv0adK3kjOUr9n93mANHhPJ.jpg',
#    'id': 583083,
#    'adult': False,
#    'backdrop_path': '/wO5QSWZPBT71gMLvrRex0bVc0V9.jpg',
#    'original_language': 'en',
#    'original_title': 'The Kissing Booth 2',
#    'genre_ids': [35, 10749],
#    'title': 'The Kissing Booth 2',
#    'vote_average': 8.3,
#    'overview': 'With college decisions looming, Elle juggles her long-distance romance with Noah, changing relationship with bestie Lee and feelings for a new classmate.',
#    'release_date': '2020-07-24'},
#   {'popularity': 183.9,
#    'id': 516486,
#    'video': False,
#    'vote_count': 668,
#    'vote_average': 7.6,
#    'title': 'Greyhound',
#    'release_date': '2020-07-10',
#    'original_language': 'en',
#    'original_title': 'Greyhound',
#    'genre_ids': [10752, 28, 18],
#    'backdrop_path': '/xXBnM6uSTk6qqCf0SRZKXcga9Ba.jpg',
#    'adult': False,
#    'overview': 'A first-time captain leads a convoy of allied ships carrying thousands of soldiers across the treacherous waters of the “Black Pit” to the front lines of WW2. With no air cover protection for 5 days, the captain and his convoy must battle the surrounding enemy Nazi U-boats in order to give the allies a chance to win the war.',
#    'poster_path': '/kjMbDciooTbJPofVXgAoFjfX8Of.jpg'},
#   {'popularity': 146.482,
#    'id': 547016,
#    'video': False,
#    'vote_count': 1401,
#    'vote_average': 7.4,
#    'title': 'The Old Guard',
#    'release_date': '2020-07-10',
#    'original_language': 'en',
#    'original_title': 'The Old Guard',
#    'genre_ids': [28, 14],
#    'backdrop_path': '/m0ObOaJBerZ3Unc74l471ar8Iiy.jpg',
#    'adult': False,
#    'overview': "Four undying warriors who've secretly protected humanity for centuries become targeted for their mysterious powers just as they discover a new immortal.",
#    'poster_path': '/cjr4NWURcVN3gW5FlHeabgBHLrY.jpg'},
#   {'popularity': 120.998,
#    'vote_count': 268,
#    'video': False,
#    'poster_path': '/jHo2M1OiH9Re33jYtUQdfzPeUkx.jpg',
#    'id': 385103,
#    'adult': False,
#    'backdrop_path': '/fKtYXUhX5fxMxzQfyUcQW9Shik6.jpg',
#    'original_language': 'en',
#    'original_title': 'Scoob!',
#    'genre_ids': [12, 16, 35, 9648, 10751],
#    'title': 'Scoob!',
#    'vote_average': 7.8,
#    'overview': 'In Scooby-Doo’s greatest adventure yet, see the never-before told story of how lifelong friends Scooby and Shaggy first met and how they joined forces with young detectives Fred, Velma, and Daphne to form the famous Mystery Inc. Now, with hundreds of cases solved, Scooby and the gang face their biggest, toughest mystery ever: an evil plot to unleash the ghost dog Cerberus upon the world. As they race to stop this global “dogpocalypse,” the gang discovers that Scooby has a secret legacy and an epic destiny greater than anyone ever imagined.',
#    'release_date': '2020-07-08'},
#   {'popularity': 107.839,
#    'vote_count': 43,
#    'video': False,
#    'poster_path': '/3ynPnBXQVT2Y0s19fDIPlWKUlxH.jpg',
#    'id': 587496,
#    'adult': False,
#    'backdrop_path': '/2gBMBfmQvHeOQQ5PiKiuxVdGs77.jpg',
#    'original_language': 'en',
#    'original_title': 'The Rental',
#    'genre_ids': [27, 53],
#    'title': 'The Rental',
#    'vote_average': 5.5,
#    'overview': 'Two couples on an oceanside getaway grow suspicious that the host of their seemingly perfect rental house may be spying on them. Before long, what should have been a celebratory weekend trip turns into something far more sinister.',
#    'release_date': '2020-07-23'},
#   {'popularity': 90.898,
#    'vote_count': 5240,
#    'video': False,
#    'poster_path': '/h4VB6m0RwcicVEZvzftYZyKXs6K.jpg',
#    'id': 495764,
#    'adult': False,
#    'backdrop_path': '/9xNOiv6DZZjH7ABoUUDP0ZynouU.jpg',
#    'original_language': 'en',
#    'original_title': 'Birds of Prey (and the Fantabulous Emancipation of One Harley Quinn)',
#    'genre_ids': [28, 35, 80, 18],
#    'title': 'Birds of Prey (and the Fantabulous Emancipation of One Harley Quinn)',
#    'vote_average': 7.2,
#    'overview': 'Harley Quinn joins forces with a singer, an assassin and a police detective to help a young girl who had a hit placed on her after she stole a rare diamond from a crime lord.',
#    'release_date': '2020-02-05'},
#   {'popularity': 87.083,
#    'vote_count': 54,
#    'video': False,
#    'poster_path': '/bUi0xPSrxrL7xOD1bIE1RtnMWtn.jpg',
#    'id': 673174,
#    'adult': False,
#    'backdrop_path': '/61uvGsh4HmhEBDGIUuSEpIjYHdF.jpg',
#    'original_language': 'es',
#    'original_title': 'Ofrenda a la tormenta',
#    'genre_ids': [80, 53],
#    'title': 'Offering to the Storm',
#    'vote_average': 6.5,
#    'overview': 'Inspector Amaia Salazar confronts the origins of her nightmares as she unfolds the darkest secrets of the Baztan valley. Part 3 in the Baztan Trilogy.',
#    'release_date': '2020-07-24'},
#   {'popularity': 80.258,
#    'vote_count': 5232,
#    'video': False,
#    'poster_path': '/aQvJ5WPzZgYVDrxLX4R6cLJCEaQ.jpg',
#    'id': 454626,
#    'adult': False,
#    'backdrop_path': '/stmYfCUGd8Iy6kAMBr6AmWqx8Bq.jpg',
#    'original_language': 'en',
#    'original_title': 'Sonic the Hedgehog',
#    'genre_ids': [28, 35, 878, 10751],
#    'title': 'Sonic the Hedgehog',
#    'vote_average': 7.5,
#    'overview': 'Based on the global blockbuster videogame franchise from Sega, Sonic the Hedgehog tells the story of the world’s speediest hedgehog as he embraces his new home on Earth. In this live-action adventure comedy, Sonic and his new best friend team up to defend the planet from the evil genius Dr. Robotnik and his plans for world domination.',
#    'release_date': '2020-02-12'},
#   {'popularity': 78.888,
#    'vote_count': 2717,
#    'video': False,
#    'poster_path': '/f4aul3FyD3jv3v4bul1IrkWZvzq.jpg',
#    'id': 508439,
#    'adult': False,
#    'backdrop_path': '/xFxk4vnirOtUxpOEWgA1MCRfy6J.jpg',
#    'original_language': 'en',
#    'original_title': 'Onward',
#    'genre_ids': [12, 16, 35, 14, 10751],
#    'title': 'Onward',
#    'vote_average': 7.9,
#    'overview': 'In a suburban fantasy world, two teenage elf brothers embark on an extraordinary quest to discover if there is still a little magic left out there.',
#    'release_date': '2020-02-29'},
#   {'popularity': 70.223,
#    'vote_count': 215,
#    'video': False,
#    'poster_path': '/hPkqY2EMqWUnFEoedukilIUieVG.jpg',
#    'id': 531876,
#    'adult': False,
#    'backdrop_path': '/n1RohH2VoK1CdVI2fXvcP19dSlm.jpg',
#    'original_language': 'en',
#    'original_title': 'The Outpost',
#    'genre_ids': [28, 18, 36, 10752],
#    'title': 'The Outpost',
#    'vote_average': 6.7,
#    'overview': 'A small unit of U.S. soldiers, alone at the remote Combat Outpost Keating, located deep in the valley of three mountains in Afghanistan, battles to defend against an overwhelming force of Taliban fighters in a coordinated attack. The Battle of Kamdesh, as it was known, was the bloodiest American engagement of the Afghan War in 2009 and Bravo Troop 3-61 CAV became one of the most decorated units of the 19-year conflict.',
#    'release_date': '2020-06-24'},
#   {'popularity': 62.264,
#    'vote_count': 36,
#    'video': False,
#    'poster_path': '/uHdxICUIRGoJjK67aOp3ykvL8ZW.jpg',
#    'id': 718867,
#    'adult': False,
#    'backdrop_path': '/53aUwtolUZxgzMr2KbDpOnD8jo3.jpg',
#    'original_language': 'en',
#    'original_title': 'The Larva Island Movie',
#    'genre_ids': [16, 10751],
#    'title': 'The Larva Island Movie',
#    'vote_average': 7.8,
#    'overview': 'Back at home, Chuck relates the island shenanigans of his larva pals Red and Yellow to a skeptical reporter in this movie sequel to the hit cartoon.',
#    'release_date': '2020-07-23'},
#   {'popularity': 60.569,
#    'vote_count': 4794,
#    'video': False,
#    'poster_path': '/y95lQLnuNKdPAzw9F9Ab8kJ80c3.jpg',
#    'id': 38700,
#    'adult': False,
#    'backdrop_path': '/upUy2QhMZEmtypPW3PdieKLAHxh.jpg',
#    'original_language': 'en',
#    'original_title': 'Bad Boys for Life',
#    'genre_ids': [28, 80, 53],
#    'title': 'Bad Boys for Life',
#    'vote_average': 7.2,
#    'overview': 'Marcus and Mike are forced to confront new threats, career changes, and midlife crises as they join the newly created elite team AMMO of the Miami police department to take down the ruthless Armando Armas, the vicious leader of a Miami drug cartel.',
#    'release_date': '2020-01-15'},
#   {'popularity': 59.383,
#    'vote_count': 23,
#    'video': False,
#    'poster_path': '/7S9RvfMBWSTlUZ4VbxDY7oLeenk.jpg',
#    'id': 581392,
#    'adult': False,
#    'backdrop_path': '/aWsVwgG324dFQS5xHEjB7OCOT9w.jpg',
#    'original_language': 'ko',
#    'original_title': '반도',
#    'genre_ids': [28, 27, 53],
#    'title': 'Peninsula',
#    'vote_average': 6,
#    'overview': 'Peninsula takes place four years after Train to Busan as the characters fight to escape the land that is in ruins due to an unprecedented disaster.',
#    'release_date': '2020-07-15'},
#   {'popularity': 55.896,
#    'vote_count': 2552,
#    'video': False,
#    'poster_path': '/5EufsDwXdY2CVttYOk2WtYhgKpa.jpg',
#    'id': 570670,
#    'adult': False,
#    'backdrop_path': '/uZMZyvarQuXLRqf3xdpdMqzdtjb.jpg',
#    'original_language': 'en',
#    'original_title': 'The Invisible Man',
#    'genre_ids': [27, 878, 53],
#    'title': 'The Invisible Man',
#    'vote_average': 7.2,
#    'overview': "When Cecilia's abusive ex takes his own life and leaves her his fortune, she suspects his death was a hoax. As a series of coincidences turn lethal, Cecilia works to prove that she is being hunted by someone nobody can see.",
#    'release_date': '2020-02-26'},
#   {'popularity': 55.193,
#    'vote_count': 2802,
#    'video': False,
#    'poster_path': '/wlfDxbGEsW58vGhFljKkcR5IxDj.jpg',
#    'id': 545609,
#    'adult': False,
#    'backdrop_path': '/1R6cvRtZgsYCkh8UFuWFN33xBP4.jpg',
#    'original_language': 'en',
#    'original_title': 'Extraction',
#    'genre_ids': [28, 18, 53],
#    'title': 'Extraction',
#    'vote_average': 7.5,
#    'overview': 'Tyler Rake, a fearless mercenary who offers his services on the black market, embarks on a dangerous mission when he is hired to rescue the kidnapped son of a Mumbai crime lord…',
#    'release_date': '2020-04-24'},
#   {'popularity': 54.502,
#    'vote_count': 2927,
#    'video': False,
#    'poster_path': '/8WUVHemHFH2ZIP6NWkwlHWsyrEL.jpg',
#    'id': 338762,
#    'adult': False,
#    'backdrop_path': '/lP5eKh8WOcPysfELrUpGhHJGZEH.jpg',
#    'original_language': 'en',
#    'original_title': 'Bloodshot',
#    'genre_ids': [28, 878],
#    'title': 'Bloodshot',
#    'vote_average': 7,
#    'overview': "After he and his wife are murdered, marine Ray Garrison is resurrected by a team of scientists. Enhanced with nanotechnology, he becomes a superhuman, biotech killing machine—'Bloodshot'. As Ray first trains with fellow super-soldiers, he cannot recall anything from his former life. But when his memories flood back and he remembers the man that killed both him and his wife, he breaks out of the facility to get revenge, only to discover that there's more to the conspiracy than he thought.",
#    'release_date': '2020-03-05'},
#   {'popularity': 54.401,
#    'vote_count': 0,
#    'video': False,
#    'poster_path': '/eGsnBB3BquzGHSqSKqoF998oDVr.jpg',
#    'id': 720748,
#    'adult': False,
#    'backdrop_path': '/bKcy3lpyHOrnvy7McmAbffmJL4W.jpg',
#    'original_language': 'en',
#    'original_title': 'The Speed Cubers',
#    'genre_ids': [99],
#    'title': 'The Speed Cubers',
#    'vote_average': 0,
#    'overview': "This documentary captures the extraordinary twists and turns in the journeys of Rubik's Cube-solving champions Max Park and Feliks Zemdegs.",
#    'release_date': '2020-07-29'},
#   {'popularity': 51.856,
#    'vote_count': 18,
#    'video': False,
#    'poster_path': '/osoQHmiOMlk1v4sNyIMkO8RF4cJ.jpg',
#    'id': 603119,
#    'adult': False,
#    'backdrop_path': '/wmue8ULgckHrTc9eXALYoDbOAq0.jpg',
#    'original_language': 'en',
#    'original_title': 'The Silencing',
#    'genre_ids': [28, 80, 53],
#    'title': 'The Silencing',
#    'vote_average': 6.7,
#    'overview': 'A reformed hunter becomes involved in a deadly game of cat and mouse when he and the local sheriff set out to track a vicious killer who may have kidnapped his daughter years ago.',
#    'release_date': '2020-07-18'},
#   {'popularity': 50.254,
#    'vote_count': 85,
#    'video': False,
#    'poster_path': '/3wZ0gxLqsPleneFSTZILmM3BE8Q.jpg',
#    'id': 539181,
#    'adult': False,
#    'backdrop_path': '/vpUUznNzW85xo02H16RaSxRNS1.jpg',
#    'original_language': 'en',
#    'original_title': 'Relic',
#    'genre_ids': [18, 27],
#    'title': 'Relic',
#    'vote_average': 6.3,
#    'overview': 'When Edna—the elderly and widowed matriarch of the family—goes missing, her daughter and granddaughter travel to their remote family home to find her. Soon after her return, they start to discover a sinister presence haunting the house and taking control of Edna.',
#    'release_date': '2020-07-03'},
#   {'popularity': 49.824,
#    'vote_count': 16,
#    'video': False,
#    'poster_path': '/xqbQtMffXwa3oprse4jiHBMBvdW.jpg',
#    'id': 601844,
#    'adult': False,
#    'backdrop_path': '/qTrpw2ZUvN7ywUu1kieEsvNDrgQ.jpg',
#    'original_language': 'en',
#    'original_title': 'Becky',
#    'genre_ids': [28, 27, 53],
#    'title': 'Becky',
#    'vote_average': 4.3,
#    'overview': "A teenager's weekend at a lake house with her father takes a turn for the worse when a group of convicts wreaks havoc on their lives.",
#    'release_date': '2020-07-23'}]}

# %%
pd.DataFrame(data)
# Out:
#     page  total_results  total_pages  \
# 0      1           8529          427
# 1      1           8529          427
# 2      1           8529          427
# 3      1           8529          427
# 4      1           8529          427
# 5      1           8529          427
# 6      1           8529          427
# 7      1           8529          427
# 8      1           8529          427
# 9      1           8529          427
# 10     1           8529          427
# 11     1           8529          427
# 12     1           8529          427
# 13     1           8529          427
# 14     1           8529          427
# 15     1           8529          427
# 16     1           8529          427
# 17     1           8529          427
# 18     1           8529          427
# 19     1           8529          427
#
#                                               results
# 0   {'popularity': 303.903, 'vote_count': 2357, 'v...
# 1   {'popularity': 183.9, 'id': 516486, 'video': F...
# 2   {'popularity': 146.482, 'id': 547016, 'video':...
# 3   {'popularity': 120.998, 'vote_count': 268, 'vi...
# 4   {'popularity': 107.839, 'vote_count': 43, 'vid...
# 5   {'popularity': 90.898, 'vote_count': 5240, 'vi...
# 6   {'popularity': 87.083, 'vote_count': 54, 'vide...
# 7   {'popularity': 80.258, 'vote_count': 5232, 'vi...
# 8   {'popularity': 78.888, 'vote_count': 2717, 'vi...
# 9   {'popularity': 70.223, 'vote_count': 215, 'vid...
# 10  {'popularity': 62.264, 'vote_count': 36, 'vide...
# 11  {'popularity': 60.569, 'vote_count': 4794, 'vi...
# 12  {'popularity': 59.383, 'vote_count': 23, 'vide...
# 13  {'popularity': 55.896, 'vote_count': 2552, 'vi...
# 14  {'popularity': 55.193, 'vote_count': 2802, 'vi...
# 15  {'popularity': 54.502, 'vote_count': 2927, 'vi...
# 16  {'popularity': 54.401, 'vote_count': 0, 'video...
# 17  {'popularity': 51.856, 'vote_count': 18, 'vide...
# 18  {'popularity': 50.254, 'vote_count': 85, 'vide...
# 19  {'popularity': 49.824, 'vote_count': 16, 'vide...

# %%
df4 = pd.DataFrame(data['results'])

# %%
df4
# Out:
#     popularity  vote_count  video                       poster_path      id  \
# 0      303.903        2357  False  /mb7wQv0adK3kjOUr9n93mANHhPJ.jpg  583083
# 1      183.900         668  False  /kjMbDciooTbJPofVXgAoFjfX8Of.jpg  516486
# 2      146.482        1401  False  /cjr4NWURcVN3gW5FlHeabgBHLrY.jpg  547016
# 3      120.998         268  False  /jHo2M1OiH9Re33jYtUQdfzPeUkx.jpg  385103
# 4      107.839          43  False  /3ynPnBXQVT2Y0s19fDIPlWKUlxH.jpg  587496
# 5       90.898        5240  False  /h4VB6m0RwcicVEZvzftYZyKXs6K.jpg  495764
# 6       87.083          54  False  /bUi0xPSrxrL7xOD1bIE1RtnMWtn.jpg  673174
# 7       80.258        5232  False  /aQvJ5WPzZgYVDrxLX4R6cLJCEaQ.jpg  454626
# 8       78.888        2717  False  /f4aul3FyD3jv3v4bul1IrkWZvzq.jpg  508439
# 9       70.223         215  False  /hPkqY2EMqWUnFEoedukilIUieVG.jpg  531876
# 10      62.264          36  False  /uHdxICUIRGoJjK67aOp3ykvL8ZW.jpg  718867
# 11      60.569        4794  False  /y95lQLnuNKdPAzw9F9Ab8kJ80c3.jpg   38700
# 12      59.383          23  False  /7S9RvfMBWSTlUZ4VbxDY7oLeenk.jpg  581392
# 13      55.896        2552  False  /5EufsDwXdY2CVttYOk2WtYhgKpa.jpg  570670
# 14      55.193        2802  False  /wlfDxbGEsW58vGhFljKkcR5IxDj.jpg  545609
# 15      54.502        2927  False  /8WUVHemHFH2ZIP6NWkwlHWsyrEL.jpg  338762
# 16      54.401           0  False  /eGsnBB3BquzGHSqSKqoF998oDVr.jpg  720748
# 17      51.856          18  False  /osoQHmiOMlk1v4sNyIMkO8RF4cJ.jpg  603119
# 18      50.254          85  False  /3wZ0gxLqsPleneFSTZILmM3BE8Q.jpg  539181
# 19      49.824          16  False  /xqbQtMffXwa3oprse4jiHBMBvdW.jpg  601844
#
#     adult                     backdrop_path original_language  \
# 0   False  /wO5QSWZPBT71gMLvrRex0bVc0V9.jpg                en
# 1   False  /xXBnM6uSTk6qqCf0SRZKXcga9Ba.jpg                en
# 2   False  /m0ObOaJBerZ3Unc74l471ar8Iiy.jpg                en
# 3   False  /fKtYXUhX5fxMxzQfyUcQW9Shik6.jpg                en
# 4   False  /2gBMBfmQvHeOQQ5PiKiuxVdGs77.jpg                en
# 5   False  /9xNOiv6DZZjH7ABoUUDP0ZynouU.jpg                en
# 6   False  /61uvGsh4HmhEBDGIUuSEpIjYHdF.jpg                es
# 7   False  /stmYfCUGd8Iy6kAMBr6AmWqx8Bq.jpg                en
# 8   False  /xFxk4vnirOtUxpOEWgA1MCRfy6J.jpg                en
# 9   False  /n1RohH2VoK1CdVI2fXvcP19dSlm.jpg                en
# 10  False  /53aUwtolUZxgzMr2KbDpOnD8jo3.jpg                en
# 11  False  /upUy2QhMZEmtypPW3PdieKLAHxh.jpg                en
# 12  False  /aWsVwgG324dFQS5xHEjB7OCOT9w.jpg                ko
# 13  False  /uZMZyvarQuXLRqf3xdpdMqzdtjb.jpg                en
# 14  False  /1R6cvRtZgsYCkh8UFuWFN33xBP4.jpg                en
# 15  False  /lP5eKh8WOcPysfELrUpGhHJGZEH.jpg                en
# 16  False  /bKcy3lpyHOrnvy7McmAbffmJL4W.jpg                en
# 17  False  /wmue8ULgckHrTc9eXALYoDbOAq0.jpg                en
# 18  False   /vpUUznNzW85xo02H16RaSxRNS1.jpg                en
# 19  False  /qTrpw2ZUvN7ywUu1kieEsvNDrgQ.jpg                en
#
#                                        original_title  \
# 0                                 The Kissing Booth 2
# 1                                           Greyhound
# 2                                       The Old Guard
# 3                                              Scoob!
# 4                                          The Rental
# 5   Birds of Prey (and the Fantabulous Emancipatio...
# 6                               Ofrenda a la tormenta
# 7                                  Sonic the Hedgehog
# 8                                              Onward
# 9                                         The Outpost
# 10                             The Larva Island Movie
# 11                                  Bad Boys for Life
# 12                                                 반도
# 13                                  The Invisible Man
# 14                                         Extraction
# 15                                          Bloodshot
# 16                                   The Speed Cubers
# 17                                      The Silencing
# 18                                              Relic
# 19                                              Becky
#
#                     genre_ids  \
# 0                 [35, 10749]
# 1             [10752, 28, 18]
# 2                    [28, 14]
# 3   [12, 16, 35, 9648, 10751]
# 4                    [27, 53]
# 5            [28, 35, 80, 18]
# 6                    [80, 53]
# 7        [28, 35, 878, 10751]
# 8     [12, 16, 35, 14, 10751]
# 9         [28, 18, 36, 10752]
# 10                [16, 10751]
# 11               [28, 80, 53]
# 12               [28, 27, 53]
# 13              [27, 878, 53]
# 14               [28, 18, 53]
# 15                  [28, 878]
# 16                       [99]
# 17               [28, 80, 53]
# 18                   [18, 27]
# 19               [28, 27, 53]
#
#                                                 title  vote_average  \
# 0                                 The Kissing Booth 2           8.3
# 1                                           Greyhound           7.6
# 2                                       The Old Guard           7.4
# 3                                              Scoob!           7.8
# 4                                          The Rental           5.5
# 5   Birds of Prey (and the Fantabulous Emancipatio...           7.2
# 6                               Offering to the Storm           6.5
# 7                                  Sonic the Hedgehog           7.5
# 8                                              Onward           7.9
# 9                                         The Outpost           6.7
# 10                             The Larva Island Movie           7.8
# 11                                  Bad Boys for Life           7.2
# 12                                          Peninsula           6.0
# 13                                  The Invisible Man           7.2
# 14                                         Extraction           7.5
# 15                                          Bloodshot           7.0
# 16                                   The Speed Cubers           0.0
# 17                                      The Silencing           6.7
# 18                                              Relic           6.3
# 19                                              Becky           4.3
#
#                                              overview release_date
# 0   With college decisions looming, Elle juggles h...   2020-07-24
# 1   A first-time captain leads a convoy of allied ...   2020-07-10
# 2   Four undying warriors who've secretly protecte...   2020-07-10
# 3   In Scooby-Doo’s greatest adventure yet, see th...   2020-07-08
# 4   Two couples on an oceanside getaway grow suspi...   2020-07-23
# 5   Harley Quinn joins forces with a singer, an as...   2020-02-05
# 6   Inspector Amaia Salazar confronts the origins ...   2020-07-24
# 7   Based on the global blockbuster videogame fran...   2020-02-12
# 8   In a suburban fantasy world, two teenage elf b...   2020-02-29
# 9   A small unit of U.S. soldiers, alone at the re...   2020-06-24
# 10  Back at home, Chuck relates the island shenani...   2020-07-23
# 11  Marcus and Mike are forced to confront new thr...   2020-01-15
# 12  Peninsula takes place four years after Train t...   2020-07-15
# 13  When Cecilia's abusive ex takes his own life a...   2020-02-26
# 14  Tyler Rake, a fearless mercenary who offers hi...   2020-04-24
# 15  After he and his wife are murdered, marine Ray...   2020-03-05
# 16  This documentary captures the extraordinary tw...   2020-07-29
# 17  A reformed hunter becomes involved in a deadly...   2020-07-18
# 18  When Edna—the elderly and widowed matriarch of...   2020-07-03
# 19  A teenager's weekend at a lake house with her ...   2020-07-23

# %%
df4[['title', 'popularity', 'release_date']]
# Out:
#                                                 title  popularity release_date
# 0                                 The Kissing Booth 2     303.903   2020-07-24
# 1                                           Greyhound     183.900   2020-07-10
# 2                                       The Old Guard     146.482   2020-07-10
# 3                                              Scoob!     120.998   2020-07-08
# 4                                          The Rental     107.839   2020-07-23
# 5   Birds of Prey (and the Fantabulous Emancipatio...      90.898   2020-02-05
# 6                               Offering to the Storm      87.083   2020-07-24
# 7                                  Sonic the Hedgehog      80.258   2020-02-12
# 8                                              Onward      78.888   2020-02-29
# 9                                         The Outpost      70.223   2020-06-24
# 10                             The Larva Island Movie      62.264   2020-07-23
# 11                                  Bad Boys for Life      60.569   2020-01-15
# 12                                          Peninsula      59.383   2020-07-15
# 13                                  The Invisible Man      55.896   2020-02-26
# 14                                         Extraction      55.193   2020-04-24
# 15                                          Bloodshot      54.502   2020-03-05
# 16                                   The Speed Cubers      54.401   2020-07-29
# 17                                      The Silencing      51.856   2020-07-18
# 18                                              Relic      50.254   2020-07-03
# 19                                              Becky      49.824   2020-07-23
